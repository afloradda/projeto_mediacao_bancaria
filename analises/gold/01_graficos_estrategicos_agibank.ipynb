# %%
"""
================================================================================
NOTEBOOK: GRAFICOS ESTRATEGICOS - ANALISE MEDIACAO BANCARIA AGIBANK
================================================================================

Objetivo: Criar 10 graficos estrategicos para analise comparativa Agibank vs Mercado

Autor: Equipe de Analise de Dados
Data: 25/02/2026
Status: Pronto para Producao

Graficos:
1. Mapa de Calor Brasil
2. Top Municipios SP (Volume + Taxa Normalizada)
3. Top Instituicoes Financeiras SP
4. Analise Campinas (Agibank vs Mercado)
5. Pontos Fracos Setor Financeiro
6. Benchmarks Setor Financeiro
7. Pontos Fracos Agibank
8. Pontos Fortes Agibank
9. Matriz de Oportunidades
10. Plano de Acao

================================================================================
"""

print("=" * 100)
print("NOTEBOOK: GRAFICOS ESTRATEGICOS - ANALISE AGIBANK")
print("=" * 100)
# Out:
# ...
# NOTEBOOK: GRAFICOS ESTRATEGICOS - ANALISE AGIBANK
# ...

# %%
# CONFIGURACAO DO AMBIENTE E IMPORTACOES

import sys
from pathlib import Path

# Obter diretorio atual
caminho_atual = Path.cwd()

# Subir 2 niveis para chegar na raiz do projeto
raiz_projeto = caminho_atual.parent.parent

# Adicionar raiz do projeto ao path
sys.path.insert(0, str(raiz_projeto))

print(f"Diretorio atual: {caminho_atual}")
print(f"Raiz do projeto: {raiz_projeto}")
print(f"Caminho adicionado ao sys.path")

# Verificar se a pasta lib existe
caminho_lib = raiz_projeto / 'lib'
print(f"\nPasta 'lib' encontrada em: {caminho_lib}")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px        
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
from datetime import datetime
import json
import urllib.request


print("\nBibliotecas basicas importadas!")

# Importar modulos customizados
from lib.carregamento import (
    carregar_base_silver,
    carregar_base_gold_sp,
    carregar_base_agibank,
    carregar_base_setorial,
    carregar_base_filtrada,
    listar_arquivos_disponiveis,
    info_base
)

from lib.cores import (
    aplicar_tema_agibank,
    configurar_plotly,
    CORES_AGIBANK,
    PALETA_CATEGORICA,
    PALETA_AZUL,
    PALETA_VERDE,
    PLOTLY_COLORS,
    PLOTLY_PALETTE,
    PLOTLY_SCALE_AZUL,
    PLOTLY_SCALE_VERDE
)

from lib.visualizacoes import (
    grafico_barras,
    grafico_linha,
    grafico_pizza,
    grafico_boxplot,
    grafico_heatmap,
    grafico_distribuicao,
    grafico_comparativo_barras
)

print("Modulos customizados importados!")

# Configuracoes
warnings.filterwarnings('ignore')
np.random.seed(42)

np.set_printoptions(
    precision=2,
    suppress=True,
    linewidth=120,
    edgeitems=5,
    threshold=1000
)

print("Configuracoes NumPy aplicadas!")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)
pd.set_option('mode.use_inf_as_na', True)

print("Configuracoes Pandas aplicadas!")

# Configurar Plotly
pio.templates.default = "plotly_white"
pio.renderers.default = "browser"

print("Plotly configurado!")
# Out:
# Diretorio atual: c:\Users\caroline.coutinho\projeto_mediacao_bancaria\analises\gold
# Raiz do projeto: c:\Users\caroline.coutinho\projeto_mediacao_bancaria
# Caminho adicionado ao sys.path
#
# Pasta 'lib' encontrada em: c:\Users\caroline.coutinho\projeto_mediacao_bancaria\lib
#
# Bibliotecas basicas importadas!
# Modulos customizados importados!
# Configuracoes NumPy aplicadas!
# Configuracoes Pandas aplicadas!
# Plotly configurado!

# %%
print("\nAplicando tema Agibank...")

# Aplicar tema customizado
aplicar_tema_agibank()
configurar_plotly()

print("OK - Tema Agibank aplicado!")

# Exibir cores disponiveis
print("\nCores Agibank disponiveis:")
for nome, cor in CORES_AGIBANK.items():
    print(f"  {nome}: {cor}")

print("\nPaletas disponiveis:")
print(f"  PALETA_CATEGORICA: {len(PALETA_CATEGORICA)} cores")
print(f"  PALETA_AZUL: {len(PALETA_AZUL)} tons")
print(f"  PALETA_VERDE: {len(PALETA_VERDE)} tons")
# Out:
# Aplicando tema Agibank...
# Tema Agibank aplicado - Tamanho: medio
# Tema Agibank aplicado ao Plotly
# OK - Tema Agibank aplicado!
#
# Cores Agibank disponiveis:
#   azul_principal: #0064f5
#   azul_medio: #0053b0
#   azul_escuro: #000f44
#   verde: #77df40
#   verde_claro: #c5ff90
#   amarelo: #ffd600
#   branco: #ffffff
#
# Paletas disponiveis:
#   PALETA_CATEGORICA: 6 cores
#   PALETA_AZUL: 3 tons
#   PALETA_VERDE: 2 tons

# %%
print("\nCriando funcoes auxiliares adicionais...")

# Primeiro, vamos ver quais cores estao disponiveis
print("\nCores disponiveis em CORES_AGIBANK:")
for chave in CORES_AGIBANK.keys():
    print(f"  - {chave}")

# Pegar a primeira cor disponivel como padrao
COR_PADRAO = list(CORES_AGIBANK.values())[0]

def formatar_numero(valor, tipo='inteiro'):
    """Formata numeros para exibicao"""
    if pd.isna(valor):
        return 'N/A'
    
    if tipo == 'inteiro':
        return f"{int(valor):,}".replace(',', '.')
    elif tipo == 'decimal':
        return f"{valor:,.2f}".replace(',', 'X').replace('.', ',').replace('X', '.')
    elif tipo == 'percentual':
        return f"{valor:.2f}%"
    elif tipo == 'moeda':
        return f"R$ {valor:,.2f}".replace(',', 'X').replace('.', ',').replace('X', '.')
    else:
        return str(valor)

def criar_anotacao(texto, x, y, cor=None):
    """Cria anotacao para graficos"""
    if cor is None:
        cor = COR_PADRAO
    
    return dict(
        x=x, y=y, text=texto,
        showarrow=True, arrowhead=2, arrowsize=1, arrowwidth=2, arrowcolor=cor,
        ax=20, ay=-30,
        font=dict(size=10, color=cor),
        bgcolor='white', bordercolor=cor, borderwidth=1
    )

def salvar_grafico(fig, nome_arquivo, pasta='graficos_estrategicos'):
    """Salva grafico em HTML e PNG"""
    caminho_pasta = Path(pasta)
    caminho_pasta.mkdir(exist_ok=True)
    
    caminho_html = caminho_pasta / f"{nome_arquivo}.html"
    fig.write_html(caminho_html)
    
    try:
        caminho_png = caminho_pasta / f"{nome_arquivo}.png"
        fig.write_image(caminho_png, width=1200, height=800)
        print(f"OK - Grafico salvo: {nome_arquivo}.html e .png")
    except:
        print(f"OK - Grafico salvo: {nome_arquivo}.html (PNG requer kaleido)")

def criar_tabela_comparativa(df, colunas, titulo):
    """Cria tabela formatada"""
    # Usar primeira cor do dicionario para header
    cor_header = list(CORES_AGIBANK.values())[0] if len(CORES_AGIBANK) > 0 else '#004E89'
    
    fig = go.Figure(data=[go.Table(
        header=dict(
            values=[f"<b>{col}</b>" for col in colunas],
            fill_color=cor_header,
            font=dict(color='white', size=12),
            align='left'
        ),
        cells=dict(
            values=[df[col] for col in colunas],
            fill_color='white',
            font=dict(size=11),
            align='left',
            height=25
        )
    )])
    
    fig.update_layout(
        title=titulo,
        height=400 + len(df) * 25,
        margin=dict(l=20, r=20, t=60, b=20)
    )
    return fig

print("OK - Funcoes auxiliares criadas!")
print("\nFuncoes disponiveis:")
print("  - formatar_numero()")
print("  - criar_anotacao()")
print("  - salvar_grafico()")
print("  - criar_tabela_comparativa()")
print("  + Funcoes da lib.visualizacoes")
# Out:
# Criando funcoes auxiliares adicionais...
#
# Cores disponiveis em CORES_AGIBANK:
#   - azul_principal
#   - azul_medio
#   - azul_escuro
#   - verde
#   - verde_claro
#   - amarelo
#   - branco
# OK - Funcoes auxiliares criadas!
#
# Funcoes disponiveis:
#   - formatar_numero()
#   - criar_anotacao()
#   - salvar_grafico()
#   - criar_tabela_comparativa()
#   + Funcoes da lib.visualizacoes

# %%
print("=" * 100)
print("CARREGANDO DADOS - SETOR BANCARIO")
print("=" * 100)

# Caminho dos dados
CAMINHO_BANCARIO = Path('../../data/gold/dados_prontos_plotagem/setor_bancario')

print(f"Caminho: {CAMINHO_BANCARIO.absolute()}")

# Carregar CSVs
df_estados_bancario = pd.read_csv(CAMINHO_BANCARIO / 'estados_bancario.csv')
df_municipios_sp_bancario = pd.read_csv(CAMINHO_BANCARIO / 'municipios_sp_bancario.csv')
df_municipios_agibank = pd.read_csv(CAMINHO_BANCARIO / 'municipios_agibank.csv')
df_instituicoes = pd.read_csv(CAMINHO_BANCARIO / 'instituicoes_bancarias_sp.csv')

print(f"\nOK - Estados: {len(df_estados_bancario)}")
print(f"OK - Municipios SP: {len(df_municipios_sp_bancario)}")
print(f"OK - Municipios Agibank: {len(df_municipios_agibank)}")
print(f"OK - Instituicoes: {len(df_instituicoes)}")

print("\n" + "=" * 100)
print("DADOS CARREGADOS!")
print("=" * 100)
# Out:
# ...
# CARREGANDO DADOS - SETOR BANCARIO
# ...
# Caminho: c:\Users\caroline.coutinho\projeto_mediacao_bancaria\analises\gold\..\..\data\gold\dados_prontos_plotagem\setor_bancario
#
# OK - Estados: 27
# OK - Municipios SP: 634
# OK - Municipios Agibank: 361
# OK - Instituicoes: 293
#
# ...
# DADOS CARREGADOS!
# ...

# %%
print("=" * 100)
print("PREVIEW DOS DADOS")
print("=" * 100)

print("\n1. ESTADOS:")
display(df_estados_bancario.head(3))

print("\n2. MUNICIPIOS SP:")
display(df_municipios_sp_bancario.head(3))

print("\n3. AGIBANK:")
display(df_municipios_agibank.head(3))

print("\n4. BANCOS:")
display(df_instituicoes.head(5))
# Out:
# ...
# PREVIEW DOS DADOS
# ...
#
# 1. ESTADOS:
#    uf    regiao  nota_media  tempo_medio  populacao  total_reclamacoes  \
# 0  AC     Norte        2.41         5.92     830018               3359
# 1  AL  Nordeste        2.29         5.96    3127683               9455
# 2  AM     Norte        2.30         6.47    3941613              18062
#
#    reclamacoes_100k  pct_resolvido
# 0            404.69           8.37
# 1            302.30           7.41
# 2            458.24           6.61
# 2. MUNICIPIOS SP:
#     municipio  total_reclamacoes  populacao  nota_media  tempo_medio  \
# 0  ADAMANTINA                156   34687.00        1.60         6.16
# 1      ADOLFO                  9    4351.00        5.00         5.00
# 2       AGUAÍ                 83   32072.00        3.36         5.57
#
#    pct_resolvido  reclamacoes_100k
# 0           1.92            449.74
# 1           0.00            206.85
# 2          10.84            258.79
# 3. AGIBANK:
# ...

# %%
print("=" * 100)
print("NUMEROS-CHAVE - SETOR BANCARIO")
print("=" * 100)

# Brasil
total_brasil = df_estados_bancario['total_reclamacoes'].sum()
nota_brasil = df_estados_bancario['nota_media'].mean()
tempo_brasil = df_estados_bancario['tempo_medio'].mean()
resol_brasil = df_estados_bancario['pct_resolvido'].mean()

# SP
sp = df_estados_bancario[df_estados_bancario['uf'] == 'SP'].iloc[0]

# Agibank
total_agibank = df_municipios_agibank['total_reclamacoes'].sum()
nota_agibank = df_municipios_agibank['nota_media'].mean()
tempo_agibank = df_municipios_agibank['tempo_medio'].mean()
resol_agibank = df_municipios_agibank['pct_resolvido'].mean()

# Exibir
print("\nBRASIL:")
print(f"  Total: {total_brasil:,}")
print(f"  Nota: {nota_brasil:.2f}")
print(f"  Tempo: {tempo_brasil:.2f} dias")
print(f"  % Resolvido: {resol_brasil:.2f}%")

print("\nSAO PAULO:")
print(f"  Total: {int(sp['total_reclamacoes']):,}")
print(f"  Nota: {sp['nota_media']:.2f}")
print(f"  Tempo: {sp['tempo_medio']:.2f} dias")
print(f"  % Resolvido: {sp['pct_resolvido']:.2f}%")

print("\nAGIBANK:")
print(f"  Total: {total_agibank:,}")
print(f"  Nota: {nota_agibank:.2f}")
print(f"  Tempo: {tempo_agibank:.2f} dias")
print(f"  % Resolvido: {resol_agibank:.2f}%")

print("\nCOMPARACAO:")
print(f"  Nota: {nota_agibank - nota_brasil:+.2f} {'(pior)' if nota_agibank < nota_brasil else '(melhor)'}")
print(f"  Tempo: {tempo_agibank - tempo_brasil:+.2f} dias {'(mais lento)' if tempo_agibank > tempo_brasil else '(mais rapido)'}")
print(f"  % Resolvido: {resol_agibank - resol_brasil:+.2f}% {'(pior)' if resol_agibank < resol_brasil else '(melhor)'}")

print("\n" + "=" * 100)
print("PRONTO PARA GRAFICOS!")
print("=" * 100)
# Out:
# ...
# NUMEROS-CHAVE - SETOR BANCARIO
# ...
#
# BRASIL:
#   Total: 1,109,438
#   Nota: 2.30
#   Tempo: 6.16 dias
#   % Resolvido: 7.16%
#
# SAO PAULO:
#   Total: 276,735
#   Nota: 2.19
#   Tempo: 6.27 dias
#   % Resolvido: 7.21%
#
# AGIBANK:
#   Total: 3,969
#   Nota: 1.87
#   Tempo: 6.75 dias
#   % Resolvido: 6.75%
#
# COMPARACAO:
#   Nota: -0.43 (pior)
#   Tempo: +0.59 dias (mais lento)
#   % Resolvido: -0.41% (pior)
#
# ...
# PRONTO PARA GRAFICOS!
# ...

# %%
print("=" * 100)
print("VALIDACAO: CAMPINAS - MERCADO vs AGIBANK")
print("=" * 100)

# Campinas - Mercado (todos os bancos)
campinas_mercado = df_municipios_sp_bancario[
    df_municipios_sp_bancario['municipio'] == 'CAMPINAS'
]

# Campinas - Agibank
campinas_agibank = df_municipios_agibank[
    df_municipios_agibank['municipio'] == 'CAMPINAS'
]

print("\nCAMPINAS - MERCADO BANCARIO (todos os bancos):")
if len(campinas_mercado) > 0:
    c_merc = campinas_mercado.iloc[0]
    print(f"  Total reclamacoes:  {int(c_merc['total_reclamacoes']):,}")
    print(f"  Populacao:          {int(c_merc['populacao']):,}")
    print(f"  Nota media:         {c_merc['nota_media']:.2f}")
    print(f"  Tempo medio:        {c_merc['tempo_medio']:.2f} dias")
    print(f"  % Resolvido:        {c_merc['pct_resolvido']:.2f}%")
else:
    print("  NAO ENCONTRADO!")

print("\nCAMPINAS - AGIBANK:")
if len(campinas_agibank) > 0:
    c_agi = campinas_agibank.iloc[0]
    print(f"  Total reclamacoes:  {int(c_agi['total_reclamacoes']):,}")
    print(f"  Populacao:          {int(c_agi['populacao']):,}")
    print(f"  Nota media:         {c_agi['nota_media']:.2f}")
    print(f"  Tempo medio:        {c_agi['tempo_medio']:.2f} dias")
    print(f"  % Resolvido:        {c_agi['pct_resolvido']:.2f}%")
else:
    print("  NAO ENCONTRADO!")

if len(campinas_mercado) > 0 and len(campinas_agibank) > 0:
    print("\n" + "=" * 100)
    print("COMPARACAO CAMPINAS:")
    print("=" * 100)
    
    print(f"\nVolume:")
    print(f"  Mercado:  {int(c_merc['total_reclamacoes']):>8,}")
    print(f"  Agibank:  {int(c_agi['total_reclamacoes']):>8,}")
    print(f"  % Agibank: {(c_agi['total_reclamacoes']/c_merc['total_reclamacoes']*100):>7.2f}%")
    
    print(f"\nQualidade:")
    print(f"                Mercado    Agibank    Diferenca")
    print(f"  Nota:         {c_merc['nota_media']:>7.2f}    {c_agi['nota_media']:>7.2f}    {c_agi['nota_media']-c_merc['nota_media']:>+7.2f}")
    print(f"  Tempo:        {c_merc['tempo_medio']:>7.2f}    {c_agi['tempo_medio']:>7.2f}    {c_agi['tempo_medio']-c_merc['tempo_medio']:>+7.2f} dias")
    print(f"  % Resolvido:  {c_merc['pct_resolvido']:>7.2f}    {c_agi['pct_resolvido']:>7.2f}    {c_agi['pct_resolvido']-c_merc['pct_resolvido']:>+7.2f}%")

print("\n" + "=" * 100)
# Out:
# ...
# VALIDACAO: CAMPINAS - MERCADO vs AGIBANK
# ...
#
# CAMPINAS - MERCADO BANCARIO (todos os bancos):
#   Total reclamacoes:  7,606
#   Populacao:          1,139,047
#   Nota media:         2.15
#   Tempo medio:        6.27 dias
#   % Resolvido:        7.43%
#
# CAMPINAS - AGIBANK:
#   Total reclamacoes:  78
#   Populacao:          1,139,047
#   Nota media:         1.92
#   Tempo medio:        6.59 dias
#   % Resolvido:        5.13%
#
# ...
# COMPARACAO CAMPINAS:
# ...
#
# Volume:
#   Mercado:     7,606
#   Agibank:        78
#   % Agibank:    1.03%
#
# Qualidade:
#                 Mercado    Agibank    Diferenca
#   Nota:            2.15       1.92      -0.23
#   Tempo:           6.27       6.59      +0.32 dias
#   % Resolvido:     7.43       5.13      -2.30%
#
# ...

# %%
# GRAFICO 1: MAPA DE CALOR BRASIL - SETOR BANCARIO 


print("\n" + "=" * 80)
print("GRAFICO 1: MAPA DE CALOR BRASIL - SETOR BANCARIO")
print("=" * 80)

# ETAPA 1: PREPARAÇÃO DE DADOS


print("\n[1/6] Preparando dados com NumPy...")

# Converter para arrays NumPy
uf = df_estados_bancario['uf'].values
regiao = df_estados_bancario['regiao'].values
total_reclamacoes = df_estados_bancario['total_reclamacoes'].values.astype(np.float64)
populacao = df_estados_bancario['populacao'].values.astype(np.float64)
reclamacoes_100k = df_estados_bancario['reclamacoes_100k'].values.astype(np.float64)
nota_media = df_estados_bancario['nota_media'].values.astype(np.float64)
tempo_medio = df_estados_bancario['tempo_medio'].values.astype(np.float64)
pct_resolvido = df_estados_bancario['pct_resolvido'].values.astype(np.float64)

print(f"   Arrays NumPy criados: {len(uf)} estados")

# ============================================================================
# ETAPA 2: CARREGAR GEOJSON DO BRASIL
# ============================================================================

print("\n[2/6] Carregando GeoJSON do Brasil...")

url_geojson = 'https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/brazil-states.geojson'

try:
    with urllib.request.urlopen(url_geojson) as response:
        geojson_brasil = json.loads(response.read())
    print("   GeoJSON carregado com sucesso!")
except:
    print("   Erro ao carregar GeoJSON online")
    geojson_brasil = None

# ============================================================================
# ETAPA 3: CALCULOS ESTATISTICOS COM NUMPY
# ============================================================================

print("\n[3/6] Calculando estatísticas...")

media_taxa = np.mean(reclamacoes_100k)
mediana_taxa = np.median(reclamacoes_100k)
desvio_taxa = np.std(reclamacoes_100k)
max_taxa = np.max(reclamacoes_100k)
min_taxa = np.min(reclamacoes_100k)

idx_max = np.argmax(reclamacoes_100k)
idx_min = np.argmin(reclamacoes_100k)

# Calcular quartis para legenda
q1 = np.percentile(reclamacoes_100k, 25)
q2 = np.percentile(reclamacoes_100k, 50)
q3 = np.percentile(reclamacoes_100k, 75)

print(f"   Média: {media_taxa:.0f}/100k")
print(f"   Q1: {q1:.0f} | Q2: {q2:.0f} | Q3: {q3:.0f}")

# Classificar estados por criticidade (NumPy)
criticidade = np.where(
    reclamacoes_100k > q3, 'ALTO',
    np.where(reclamacoes_100k > q2, 'MODERADO-ALTO',
    np.where(reclamacoes_100k > q1, 'MODERADO-BAIXO', 'BAIXO'))
)

# ============================================================================
# ETAPA 4: PREPARAR CUSTOMDATA
# ============================================================================

print("\n[4/6] Preparando dados para visualização...")

# Criar ranking (NumPy)
ranking = np.argsort(np.argsort(reclamacoes_100k)[::-1]) + 1

customdata_matrix = np.column_stack([
    total_reclamacoes,
    populacao,
    nota_media,
    tempo_medio,
    pct_resolvido,
    ranking
])

# ============================================================================
# ETAPA 5: CRIAR MAPA COM CORES AGIBANK
# ============================================================================

print("\n[5/6] Gerando mapa interativo...")

fig = go.Figure()

if geojson_brasil:
    colorscale_agibank = [
        [0.0, CORES_AGIBANK['verde_claro']],
        [0.15, CORES_AGIBANK['verde']],
        [0.30, CORES_AGIBANK['amarelo']],
        [0.50, '#FFA500'],
        [0.65, CORES_AGIBANK['azul_principal']],
        [0.80, CORES_AGIBANK['azul_medio']],
        [1.0, CORES_AGIBANK['azul_escuro']]
    ]
    
    fig.add_trace(go.Choropleth(
    geojson=geojson_brasil,
    locations=uf,
    z=reclamacoes_100k,
    featureidkey="properties.sigla",
    colorscale=colorscale_agibank,
    text=uf,
    marker_line_color='white',
    marker_line_width=2,
    zmin=min_taxa,
    zmax=max_taxa,
    colorbar=dict(
        # ... (mantém o colorbar como está)
    ),
    hovertemplate=(
        # CABEÇALHO
        '<b style="font-size:20px; color:#000f44">%{text}</b><br>'
        '<span style="font-size:11px; color:#999999">Ranking: %{customdata[5]}º de 27</span>'
        '<br><br>'
        
        # TAXA NORMALIZADA
        '<span style="font-size:13px; color:#666666"><b>TAXA NORMALIZADA</b></span><br><br>'
        '<span style="font-size:24px; color:#000f44"><b>%{z:.0f}</b></span> '
        '<span style="font-size:12px; color:#777777">por 100k hab</span>'
        '<br><br>'
        
        # VOLUME TOTAL
        '<span style="font-size:13px; color:#666666"><b>VOLUME TOTAL</b></span><br>'
        '<span style="font-size:18px; color:#000f44"><b>%{customdata[0]:,.0f}</b></span> '
        '<span style="font-size:11px; color:#777777">reclamações</span>'
        '<br><br>'
        
        # POPULAÇÃO
        '<span style="font-size:13px; color:#666666"><b>POPULAÇÃO</b></span><br>'
        '<span style="font-size:16px; color:#333333"><b>%{customdata[1]:,.0f}</b></span> '
        '<span style="font-size:11px; color:#777777">habitantes</span>'
        '<br><br>'
        
        # INDICADORES (LISTA VERTICAL)
        '<span style="font-size:13px; color:#666666"><b>INDICADORES DE QUALIDADE</b></span><br>'
        '<span style="font-size:12px; color:#444444">'
        '• <b>Nota Média:</b> %{customdata[2]:.2f}/5.0<br>'
        '• <b>Tempo Resposta:</b> %{customdata[3]:.1f} dias<br>'
        '• <b>Taxa Resolução:</b> %{customdata[4]:.1f}%'
        '</span>'
        '<extra></extra>'
    ),
    customdata=customdata_matrix
))

fig.update_geos(
    fitbounds="locations",
    visible=False,
    bgcolor='#F8F9FA'
)

fig.update_layout(
    title={
        'text': (
            f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:26px">Gráfico 1: Mapa de Calor - Setor Bancário Brasil</b><br>'
            '<span style="font-size:15px; color:#666666">Taxa de Reclamações por 100 mil habitantes (2025)</span><br>'
            '<span style="font-size:12px; color:#999999">Fonte: Consumidor.gov.br | Análise: Projeto Agibank</span>'
        ),
        'x': 0.5,
        'xanchor': 'center',
        'font': {'family': 'Arial'}
    },
    height=750,
    paper_bgcolor='white',
    margin=dict(t=120, l=10, r=200, b=10),
    hoverlabel=dict(
        bgcolor='rgba(255, 255, 255, 0.98)',
        font_size=13,
        font_family='Arial',
        bordercolor=CORES_AGIBANK['azul_escuro'],
        align='left'
    )
)

# Título da barra de cor
fig.add_annotation(
    text='<b>Taxa/100k hab</b>',
    xref="paper", yref="paper",
    x=1.01, y=0.995,  # ← AUMENTE este valor
    xanchor='left', yanchor='bottom',
    showarrow=False,
    font=dict(size=12, color='#1a1a1a', family='Arial')
)

# ESTATÍSTICAS (canto superior esquerdo)
fig.add_annotation(
    text=(
        f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:16px">ESTATÍSTICAS BRASIL</b><br><br>'
        f'<span style="font-size:13px; color:#333333">'
        f'<b>Total de Reclamações:</b><br>'
        f'<br>'
        f'<span style="font-size:20px; color:{CORES_AGIBANK["azul_principal"]}"><b>{int(np.sum(total_reclamacoes)):,}</b></span>'
        f'</span><br><br>'
        f'<span style="font-size:12px; color:#555555">'
        f'<b>Taxa Média:</b> {media_taxa:.0f}/100k<br>'
        f'<b>Mediana:</b> {mediana_taxa:.0f}/100k<br>'
        f'<b>Desvio Padrão:</b> ±{desvio_taxa:.0f}<br><br>'
        f'<b>Maior Taxa:</b> {uf[idx_max]} ({max_taxa:.0f}/100k)<br>'
        f'<b>Menor Taxa:</b> {uf[idx_min]} ({min_taxa:.0f}/100k)<br><br>'
        f'<b>Distribuição por Quartil:</b><br>'
        f'Q1 (25%): até {q1:.0f}/100k<br>'
        f'Q2 (50%): até {q2:.0f}/100k<br>'
        f'Q3 (75%): até {q3:.0f}/100k<br>'
        f'Q4 (100%): até {max_taxa:.0f}/100k'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=0.01, y=0.99,
    xanchor='left', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.97)',
    bordercolor=CORES_AGIBANK['azul_principal'],
    borderwidth=3,
    font=dict(color='#1a1a1a', family='Arial'),
    align='left',
    borderpad=15
)

# LEGENDA (canto inferior esquerdo) - ÚNICA VERSÃO
fig.add_annotation(
    text=(
        f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:14px">LEGENDA</b><br><br>'
        f'<span style="font-size:12px; color:#333333">'
        f'🟢 <b>Muito Baixo</b> (< {q1:.0f})<br>'
        f'🟡 <b>Baixo</b> ({q1:.0f} - {q2:.0f})<br>'
        f'🟠 <b>Moderado</b> ({q2:.0f} - {q3:.0f})<br>'
        f'🔵 <b>Alto</b> ({q3:.0f} - {max_taxa*.8:.0f})<br>'
        f'🔴 <b>Muito Alto</b> (> {max_taxa*.8:.0f})<br><br>'
        f'<span style="font-size:10px; color:#888888">'
        f'Cores: Verde → Amarelo → Azul<br>'
        f'Intensidade indica criticidade'
        f'</span>'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=0.01, y=0.32,
    xanchor='left', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.97)',
    bordercolor=CORES_AGIBANK['verde'],
    borderwidth=2,
    font=dict(color='#1a1a1a', family='Arial'),
    align='left',
    borderpad=12
)

# RODAPÉ COM INSIGHT - ÚNICA VERSÃO
fig.add_annotation(
    text=(
        f'<span style="font-size:11px; color:#666666">'
        f'<b>Insight:</b> Estados com maior taxa não necessariamente têm maior volume absoluto. '
        f'A normalização por população permite comparação justa entre regiões de tamanhos diferentes.'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=0.5, y=-0.02,
    xanchor='center', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.95)',
    bordercolor='#DDDDDD',
    borderwidth=1,
    font=dict(color='#555555', family='Arial'),
    align='center',
    borderpad=8
)

fig.show()

# ============================================================================
# ETAPA 6: SALVAR
# ============================================================================

print("\n[6/6] Salvando gráfico...")

CAMINHO_GRAFICOS = Path('graficos_estrategicos')
CAMINHO_GRAFICOS.mkdir(exist_ok=True)
fig.write_html(CAMINHO_GRAFICOS / 'grafico_01_mapa_brasil.html')

print(f"✅ Gráfico salvo em: {CAMINHO_GRAFICOS / 'grafico_01_mapa_brasil.html'}")

# ============================================================================
# RESUMO EXECUTIVO COM NUMPY
# ============================================================================

print(f"\n" + "="*80)
print("RESUMO EXECUTIVO - ANÁLISE COM NUMPY")
print("="*80)

# Ranking completo (NumPy)
ranking_indices = np.argsort(reclamacoes_100k)[::-1]

print(f"\nTop 5 Estados - MAIOR Taxa/100k:")
for i, idx in enumerate(ranking_indices[:5], 1):
    print(f"   {i}º {uf[idx]:2s} | {reclamacoes_100k[idx]:>6.0f}/100k | "
          f"{int(total_reclamacoes[idx]):>8,} recl | Nota: {nota_media[idx]:.2f}")

print(f"\nTop 5 Estados - MENOR Taxa/100k:")
for i, idx in enumerate(ranking_indices[-5:][::-1], 1):
    print(f"   {i}º {uf[idx]:2s} | {reclamacoes_100k[idx]:>6.0f}/100k | "
          f"{int(total_reclamacoes[idx]):>8,} recl | Nota: {nota_media[idx]:.2f}")

# Análise por região
print(f"\nAnálise por Região:")
regioes_unicas = np.unique(regiao)
for reg in regioes_unicas:
    mask = regiao == reg
    taxa_media_regiao = np.mean(reclamacoes_100k[mask])
    total_regiao = np.sum(total_reclamacoes[mask])
    qtd_estados = np.sum(mask)
    print(f"   {reg:15s} | Média: {taxa_media_regiao:>6.0f}/100k | "
          f"Total: {int(total_regiao):>8,} | Estados: {qtd_estados}")

# Distribuição por criticidade
print(f"\nDistribuição por Criticidade:")
unique_crit, counts_crit = np.unique(criticidade, return_counts=True)
for crit, count in zip(unique_crit, counts_crit):
    pct = (count / len(uf)) * 100
    print(f"   {crit:15s}: {count:2d} estados ({pct:.1f}%)")

print(f"\n" + "="*80)
# Out:
# ...
# GRAFICO 1: MAPA DE CALOR BRASIL - SETOR BANCARIO
# ...
#
# [1/6] Preparando dados com NumPy...
#    Arrays NumPy criados: 27 estados
#
# [2/6] Carregando GeoJSON do Brasil...
#    GeoJSON carregado com sucesso!
#
# [3/6] Calculando estatísticas...
#    Média: 514/100k
#    Q1: 392 | Q2: 496 | Q3: 616
#
# [4/6] Preparando dados para visualização...
#
# [5/6] Gerando mapa interativo...
#
# [6/6] Salvando gráfico...
# ✅ Gráfico salvo em: graficos_estrategicos\grafico_01_mapa_brasil.html
#
# ...
# RESUMO EXECUTIVO - ANÁLISE COM NUMPY
# ...
#
# Top 5 Estados - MAIOR Taxa/100k:
#    1º DF |   1209/100k |   34,062 recl | Nota: 2.32
#    2º SC |    662/100k |   50,381 recl | Nota: 2.29
#    3º MT |    658/100k |   24,089 recl | Nota: 2.32
#    4º MG |    643/100k |  132,043 recl | Nota: 2.15
#    5º RJ |    641/100k |  102,950 recl | Nota: 2.21
#
# Top 5 Estados - MENOR Taxa/100k:
#    1º AL |    302/100k |    9,455 recl | Nota: 2.29
#    2º PA |    307/100k |   24,961 recl | Nota: 2.32
# ...

# %%
# ============================================================================
# GRAFICO 2: MAPA DE CALOR BRASIL - VOLUME ABSOLUTO (VERSÃO FINAL COMPLETA)
# ============================================================================

print("\n" + "=" * 80)
print("GRAFICO 2: MAPA DE CALOR BRASIL - VOLUME ABSOLUTO DE RECLAMAÇÕES")
print("=" * 80)

# ============================================================================
# ETAPA 1: CALCULOS ESTATISTICOS - VOLUME ABSOLUTO
# ============================================================================

print("\n[1/5] Calculando estatísticas de volume absoluto...")

media_volume = np.mean(total_reclamacoes)
mediana_volume = np.median(total_reclamacoes)
desvio_volume = np.std(total_reclamacoes)
max_volume = np.max(total_reclamacoes)
min_volume = np.min(total_reclamacoes)

idx_max_vol = np.argmax(total_reclamacoes)
idx_min_vol = np.argmin(total_reclamacoes)

# Calcular quartis para volume
q1_vol = np.percentile(total_reclamacoes, 25)
q2_vol = np.percentile(total_reclamacoes, 50)
q3_vol = np.percentile(total_reclamacoes, 75)

print(f"   Média: {media_volume:.0f} reclamações")
print(f"   Q1: {q1_vol:.0f} | Q2: {q2_vol:.0f} | Q3: {q3_vol:.0f}")

# Classificar por volume
criticidade_volume = np.where(
    total_reclamacoes > q3_vol, 'MUITO ALTO',
    np.where(total_reclamacoes > q2_vol, 'ALTO',
    np.where(total_reclamacoes > q1_vol, 'MODERADO', 'BAIXO'))
)

# ============================================================================
# ETAPA 2: PREPARAR CUSTOMDATA PARA VOLUME
# ============================================================================

print("\n[2/5] Preparando dados para visualização...")

# Criar ranking por volume (NumPy)
ranking_volume = np.argsort(np.argsort(total_reclamacoes)[::-1]) + 1

# Calcular % do total nacional
pct_nacional = (total_reclamacoes / np.sum(total_reclamacoes)) * 100

customdata_volume = np.column_stack([
    reclamacoes_100k,
    populacao,
    nota_media,
    tempo_medio,
    pct_resolvido,
    ranking_volume,
    pct_nacional
])

# ============================================================================
# ETAPA 3: CRIAR MAPA DE VOLUME ABSOLUTO - CORES AGIBANK
# ============================================================================

print("\n[3/5] Gerando mapa de volume absoluto...")

fig2 = go.Figure()

if geojson_brasil:
    # Escala de cores Agibank
    colorscale_volume = [
        [0.0, CORES_AGIBANK['verde_claro']],
        [0.20, CORES_AGIBANK['verde']],
        [0.40, CORES_AGIBANK['amarelo']],
        [0.60, '#FFA500'],
        [0.75, CORES_AGIBANK['azul_principal']],
        [0.90, CORES_AGIBANK['azul_medio']],
        [1.0, CORES_AGIBANK['azul_escuro']]
    ]
    
    fig2.add_trace(go.Choropleth(
        geojson=geojson_brasil,
        locations=uf,
        z=total_reclamacoes,
        featureidkey="properties.sigla",
        colorscale=colorscale_volume,
        text=uf,
        marker_line_color='white',
        marker_line_width=2,
        zmin=min_volume,
        zmax=max_volume,
        colorbar=dict(
            title=None,
            tickfont=dict(size=11, color='#333333', family='Arial'),
            len=0.65,
            thickness=22,
            x=1.01,
            y=0.5,
            xanchor='left',
            yanchor='middle',
            bgcolor='rgba(255,255,255,0.95)',
            bordercolor='#CCCCCC',
            borderwidth=2,
            outlinecolor='#999999',
            outlinewidth=1,
            tickmode='array',
            tickvals=[min_volume, q1_vol, q2_vol, q3_vol, max_volume],
            ticktext=[
            ],
            ticklen=6,
            tickwidth=1.5,
            tickcolor='#666666',
            ticks='outside',
            showticklabels=True,
            lenmode='fraction',
            thicknessmode='pixels'
        ),
        hovertemplate=(
            # CABEÇALHO
            '<b style="font-size:20px; color:#000f44">%{text}</b><br>'
            '<span style="font-size:11px; color:#999999">Ranking: %{customdata[5]}º de 27</span>'
            '<br><br>'
            
            # VOLUME ABSOLUTO (DESTAQUE)
            '<span style="font-size:13px; color:#666666"><b>VOLUME TOTAL</b></span><br>'
            '<br>'
            '<span style="font-size:26px; color:#000f44"><b>%{z:,.0f}</b></span> '
            '<span style="font-size:12px; color:#777777">reclamações</span>'
            '<br><br>'
            
            # % DO TOTAL NACIONAL
            '<span style="font-size:13px; color:#666666"><b>PARTICIPAÇÃO NACIONAL</b></span><br>'
            '<br>'
            '<span style="font-size:20px; color:#FF6B35"><b>%{customdata[6]:.2f}%</b></span> '
            '<span style="font-size:11px; color:#777777">do total Brasil</span>'
            '<br><br>'
            
            # TAXA NORMALIZADA (secundária)
            '<span style="font-size:13px; color:#666666"><b>TAXA NORMALIZADA</b></span><br>'
            '<span style="font-size:16px; color:#333333"><b>%{customdata[0]:.0f}</b></span> '
            '<span style="font-size:11px; color:#777777">por 100k hab</span>'
            '<br><br>'
            
            # POPULAÇÃO
            '<span style="font-size:13px; color:#666666"><b>POPULAÇÃO</b></span><br>'
            '<span style="font-size:14px; color:#333333"><b>%{customdata[1]:,.0f}</b></span> '
            '<span style="font-size:10px; color:#777777">habitantes</span>'
            '<br><br>'
            
            # INDICADORES
            '<span style="font-size:13px; color:#666666"><b>INDICADORES DE QUALIDADE</b></span><br>'
            '<span style="font-size:12px; color:#444444">'
            '• <b>Nota Média:</b> %{customdata[2]:.2f}/5.0<br>'
            '• <b>Tempo Resposta:</b> %{customdata[3]:.1f} dias<br>'
            '• <b>Taxa Resolução:</b> %{customdata[4]:.1f}%'
            '</span>'
            '<extra></extra>'
        ),
        customdata=customdata_volume
    ))

# ============================================================================
# CONFIGURAÇÕES DO MAPA E LAYOUT
# ============================================================================

fig2.update_geos(
    fitbounds="locations",
    visible=False,
    bgcolor='#F8F9FA'
)

fig2.update_layout(
    title={
        'text': (
            f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:26px">Gráfico 2: Mapa de Calor - Volume Absoluto de Reclamações</b><br>'
            '<span style="font-size:15px; color:#666666">Total de reclamações por estado - Setor Bancário (2025)</span><br>'
            '<span style="font-size:12px; color:#999999">Fonte: Consumidor.gov.br | Análise: Projeto Agibank</span>'
        ),
        'x': 0.5,
        'xanchor': 'center',
        'font': {'family': 'Arial'}
    },
    height=750,
    paper_bgcolor='white',
    margin=dict(t=120, l=10, r=200, b=10),
    hoverlabel=dict(
        bgcolor='rgba(255, 255, 255, 0.98)',
        font_size=13,
        font_family='Arial',
        bordercolor=CORES_AGIBANK['azul_escuro'],
        align='left'
    )
)

# ============================================================================
# ANOTAÇÕES
# ============================================================================

# Título da barra de cor
fig2.add_annotation(
    text='<b>Volume de Reclamações</b>',
    xref="paper", yref="paper",
    x=1.01, y=0.835,
    xanchor='left', yanchor='bottom',
    showarrow=False,
    font=dict(size=12, color='#1a1a1a', family='Arial')
)

# ESTATÍSTICAS (canto superior esquerdo)
fig2.add_annotation(
    text=(
        f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:16px">ESTATÍSTICAS - VOLUME ABSOLUTO</b><br><br>'
        
        f'<span style="font-size:13px; color:#333333">'
        f'<b>Total Brasil:</b><br>'
        f'<br>'
        f'<span style="font-size:22px; color:{CORES_AGIBANK["azul_principal"]}"><b>{int(np.sum(total_reclamacoes)):,}</b></span> '
        f'<span style="font-size:11px; color:#777777">reclamações</span>'
        f'</span><br><br>'
        
        f'<span style="font-size:12px; color:#555555">'
        f'<b>Média por Estado:</b> {int(media_volume):,}<br>'
        f'{int(mediana_volume):,}<br>'
        f'<b>Desvio Padrão:</b> ±{int(desvio_volume):,}<br><br>'
        
        f'<b>Maior Volume:</b><br>'
        f'{uf[idx_max_vol]} - {int(max_volume):,} ({pct_nacional[idx_max_vol]:.1f}%)<br><br>'
        
        f'<b>Menor Volume:</b><br>'
        f'{uf[idx_min_vol]} - {int(min_volume):,} ({pct_nacional[idx_min_vol]:.2f}%)<br><br>'
        
        f'<b>Concentração:</b><br>'
        f'Top 3 estados = {np.sum(pct_nacional[np.argsort(total_reclamacoes)[-3:]]):.1f}% do total'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=0.01, y=0.99,
    xanchor='left', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.97)',
    bordercolor=CORES_AGIBANK['azul_principal'],
    borderwidth=3,
    font=dict(color='#1a1a1a', family='Arial'),
    align='left',
    borderpad=15
)

# LEGENDA (canto inferior esquerdo)
fig2.add_annotation(
    text=(
        f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:14px">LEGENDA</b><br><br>'
        f'<span style="font-size:12px; color:#333333">'
        f'🟢 <b>Muito Baixo</b> (< {int(q1_vol):,})<br>'
        f'🟡 <b>Baixo</b> ({int(q1_vol):,} - {int(q2_vol):,})<br>'
        f'🟠 <b>Moderado</b> ({int(q2_vol):,} - {int(q3_vol):,})<br>'
        f'🔵 <b>Alto</b> ({int(q3_vol):,} - {int(max_volume*.8):,})<br>'
        f'🔴 <b>Muito Alto</b> (> {int(max_volume*.8):,})<br><br>'
        f'<span style="font-size:10px; color:#888888">'
        f'Cores: Verde → Amarelo → Azul<br>'
        f'Intensidade indica volume'
        f'</span>'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=0.01, y=0.32,
    xanchor='left', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.97)',
    bordercolor=CORES_AGIBANK['verde'],
    borderwidth=2,
    font=dict(color='#1a1a1a', family='Arial'),
    align='left',
    borderpad=12
)

# RODAPÉ COM INSIGHT
fig2.add_annotation(
    text=(
        f'<span style="font-size:11px; color:#666666">'
        f'<b>Insight:</b> Estados mais populosos tendem a ter maior volume absoluto. '
        f'Para análise proporcional, consulte o Gráfico 1 (taxa normalizada por 100k habitantes).'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=0.5, y=-0.02,
    xanchor='center', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.95)',
    bordercolor='#DDDDDD',
    borderwidth=1,
    font=dict(color='#555555', family='Arial'),
    align='center',
    borderpad=8
)

fig2.show()

# ============================================================================
# ETAPA 4: SALVAR
# ============================================================================

print("\n[4/5] Salvando gráfico...")

fig2.write_html(CAMINHO_GRAFICOS / 'grafico_02_mapa_volume_absoluto.html')

print(f"✅ Gráfico salvo em: {CAMINHO_GRAFICOS / 'grafico_02_mapa_volume_absoluto.html'}")

# ============================================================================
# ETAPA 5: RESUMO EXECUTIVO - VOLUME ABSOLUTO
# ============================================================================

print(f"\n[5/5] Gerando resumo executivo...")

print(f"\n" + "="*80)
print("RESUMO EXECUTIVO - VOLUME ABSOLUTO")
print("="*80)

# Ranking por volume
ranking_vol_indices = np.argsort(total_reclamacoes)[::-1]

print(f"\n🔵 Top 10 Estados - MAIOR Volume Absoluto:")
print(f"{'Pos':<4} {'UF':<4} {'Volume':>12} {'% Brasil':>10} {'Taxa/100k':>10} {'Nota':>6}")
print("-" * 60)
for i, idx in enumerate(ranking_vol_indices[:10], 1):
    print(f"{i:<4} {uf[idx]:<4} {int(total_reclamacoes[idx]):>12,} "
          f"{pct_nacional[idx]:>9.2f}% {reclamacoes_100k[idx]:>9.0f} "
          f"{nota_media[idx]:>6.2f}")

print(f"\n🟢 Top 5 Estados - MENOR Volume Absoluto:")
print(f"{'Pos':<4} {'UF':<4} {'Volume':>12} {'% Brasil':>10} {'Taxa/100k':>10} {'Nota':>6}")
print("-" * 60)
for i, idx in enumerate(ranking_vol_indices[-5:][::-1], 1):
    print(f"{i:<4} {uf[idx]:<4} {int(total_reclamacoes[idx]):>12,} "
          f"{pct_nacional[idx]:>9.2f}% {reclamacoes_100k[idx]:>9.0f} "
          f"{nota_media[idx]:>6.2f}")

# Concentração geográfica
print(f"\n📊 Análise de Concentração:")
top3_vol = np.sum(total_reclamacoes[ranking_vol_indices[:3]])
top5_vol = np.sum(total_reclamacoes[ranking_vol_indices[:5]])
top10_vol = np.sum(total_reclamacoes[ranking_vol_indices[:10]])
total_brasil = np.sum(total_reclamacoes)

print(f"   Top 3 estados:  {int(top3_vol):>10,} ({(top3_vol/total_brasil)*100:.1f}% do total)")
print(f"   Top 5 estados:  {int(top5_vol):>10,} ({(top5_vol/total_brasil)*100:.1f}% do total)")
print(f"   Top 10 estados: {int(top10_vol):>10,} ({(top10_vol/total_brasil)*100:.1f}% do total)")

# Comparação Volume x Taxa
print(f"\n⚖️ Comparação: Volume Absoluto vs Taxa Normalizada:")
print(f"{'Estado':<8} {'Rank Volume':<12} {'Rank Taxa':<12} {'Diferença':>10}")
print("-" * 50)
for idx in ranking_vol_indices[:10]:
    rank_vol = int(ranking_volume[idx])
    rank_taxa = int(ranking[idx])
    diff = rank_taxa - rank_vol
    sinal = "↑" if diff > 0 else "↓" if diff < 0 else "="
    print(f"{uf[idx]:<8} {rank_vol:<12} {rank_taxa:<12} {sinal} {abs(diff):>9}")

print(f"\n" + "="*80)
# Out:
# ...
# GRAFICO 2: MAPA DE CALOR BRASIL - VOLUME ABSOLUTO DE RECLAMAÇÕES
# ...
#
# [1/5] Calculando estatísticas de volume absoluto...
#    Média: 41090 reclamações
#    Q1: 11432 | Q2: 24089 | Q3: 46832
#
# [2/5] Preparando dados para visualização...
#
# [3/5] Gerando mapa de volume absoluto...
#
# [4/5] Salvando gráfico...
# ✅ Gráfico salvo em: graficos_estrategicos\grafico_02_mapa_volume_absoluto.html
#
# [5/5] Gerando resumo executivo...
#
# ...
# RESUMO EXECUTIVO - VOLUME ABSOLUTO
# ...
#
# 🔵 Top 10 Estados - MAIOR Volume Absoluto:
# Pos  UF         Volume   % Brasil  Taxa/100k   Nota
# ------------------------------------------------------------
# 1    SP        276,735     24.94%       623   2.19
# 2    MG        132,043     11.90%       643   2.15
# 3    RJ        102,950      9.28%       641   2.21
# 4    PR         70,755      6.38%       618   2.23
# 5    BA         62,237      5.61%       440   2.09
# 6    RS         59,647      5.38%       548   2.19
# ...

# %%
# ============================================================================
# GRAFICO 3: TOP INSTITUIÇÕES FINANCEIRAS - SÃO PAULO
# ============================================================================

print("\n" + "=" * 80)
print("GRAFICO 3: TOP INSTITUIÇÕES FINANCEIRAS - SÃO PAULO")
print("=" * 80)

# ============================================================================
# ETAPA 1: CARREGAR DADOS DAS INSTITUIÇÕES DE SP
# ============================================================================

print("\n[1/5] Carregando dados de instituições bancárias de SP...")

# Caminho correto baseado na estrutura mostrada
caminho_base = Path('c:/Users/caroline.coutinho/projeto_mediacao_bancaria/data/gold/dados_prontos_plotagem/setor_bancario')
caminho_inst_sp = caminho_base / 'instituicoes_bancarias_sp.csv'

# Verificar se arquivo existe
if not caminho_inst_sp.exists():
    print(f"   ⚠️ Arquivo não encontrado em: {caminho_inst_sp}")
    print(f"   Tentando caminho alternativo...")
    
    # Tentar caminho relativo
    caminho_inst_sp = Path('../../data/gold/dados_prontos_plotagem/setor_bancario/instituicoes_bancarias_sp.csv')
    
    if not caminho_inst_sp.exists():
        print(f"   ❌ Arquivo ainda não encontrado!")
        print(f"   Por favor, verifique o caminho correto.")
        
        # Listar arquivos disponíveis
        try:
            pasta = Path('../../data/gold/dados_prontos_plotagem/setor_bancario')
            if pasta.exists():
                print(f"\n   Arquivos disponíveis na pasta:")
                for arquivo in pasta.glob('*.csv'):
                    print(f"      - {arquivo.name}")
        except:
            pass
        
        raise FileNotFoundError("Arquivo de instituições não encontrado!")

# Carregar dados
df_inst_sp = pd.read_csv(caminho_inst_sp)

print(f"   ✅ Dados carregados: {len(df_inst_sp):,} instituições")
print(f"   Colunas disponíveis: {list(df_inst_sp.columns)}")

# Verificar primeiras linhas
print("\n   Amostra dos dados:")
print(df_inst_sp.head(3))

# ============================================================================
# ETAPA 2: PREPARAR DADOS PARA VISUALIZAÇÃO
# ============================================================================

print("\n[2/5] Preparando dados para visualização...")

# Copiar dados
df_top_sp = df_inst_sp.copy()

# Identificar nome da coluna de instituição e reclamações
col_instituicao = df_top_sp.columns[0]  # Primeira coluna
col_reclamacoes = df_top_sp.columns[1]  # Segunda coluna

print(f"   Coluna instituição: {col_instituicao}")
print(f"   Coluna reclamações: {col_reclamacoes}")

# Limpar dados
df_top_sp = df_top_sp.dropna(subset=[col_instituicao, col_reclamacoes])
df_top_sp = df_top_sp[df_top_sp[col_reclamacoes] > 0]

# Ordenar por volume
df_top_sp = df_top_sp.sort_values(by=col_reclamacoes, ascending=False)

# Selecionar Top 15
df_top15_sp = df_top_sp.head(15).copy()

print(f"   Total de instituições: {len(df_top_sp)}")
print(f"   Top 15 selecionadas")

# ============================================================================
# ETAPA 3: CONVERTER PARA NUMPY
# ============================================================================

print("\n[3/5] Calculando estatísticas com NumPy...")

# Extrair colunas
instituicoes = df_top15_sp[col_instituicao].values
reclamacoes = df_top15_sp[col_reclamacoes].values.astype(np.float64)

# Extrair outras colunas se existirem
if len(df_top15_sp.columns) > 2:
    notas = df_top15_sp.iloc[:, 2].values.astype(np.float64)
else:
    notas = np.full(len(instituicoes), 3.0)

if len(df_top15_sp.columns) > 3:
    tempos = df_top15_sp.iloc[:, 3].values.astype(np.float64)
else:
    tempos = np.full(len(instituicoes), 7.0)

if len(df_top15_sp.columns) > 4:
    pct_resolv = df_top15_sp.iloc[:, 4].values.astype(np.float64)
else:
    pct_resolv = np.full(len(instituicoes), 75.0)

# Calcular % do total de SP
total_sp = np.sum(df_top_sp[col_reclamacoes])
pct_total_sp = (reclamacoes / total_sp) * 100

# Estatísticas
media_reclamacoes = np.mean(reclamacoes)
mediana_reclamacoes = np.median(reclamacoes)
total_top15 = np.sum(reclamacoes)
pct_top15_sp = (total_top15 / total_sp) * 100

print(f"   Total SP: {int(total_sp):,} reclamações")
print(f"   Média (Top 15): {media_reclamacoes:.0f}")
print(f"   Top 15 representa: {pct_top15_sp:.1f}% do total")

# ============================================================================
# ETAPA 4: CRIAR GRÁFICO DE BARRAS
# ============================================================================

print("\n[4/5] Gerando gráfico de barras...")

# Inverter ordem (maior no topo)
instituicoes_plot = instituicoes[::-1]
reclamacoes_plot = reclamacoes[::-1]
notas_plot = notas[::-1]
tempos_plot = tempos[::-1]
pct_resolv_plot = pct_resolv[::-1]
pct_total_sp_plot = pct_total_sp[::-1]
ranking_plot = np.arange(15, 0, -1)

# Cores por quartil
q1 = np.percentile(reclamacoes, 25)
q2 = np.percentile(reclamacoes, 50)
q3 = np.percentile(reclamacoes, 75)

cores_barras = []
for val in reclamacoes_plot:
    if val >= q3:
        cores_barras.append(CORES_AGIBANK['azul_escuro'])
    elif val >= q2:
        cores_barras.append(CORES_AGIBANK['azul_medio'])
    elif val >= q1:
        cores_barras.append(CORES_AGIBANK['azul_principal'])
    else:
        cores_barras.append(CORES_AGIBANK['verde'])

fig3 = go.Figure()

fig3.add_trace(go.Bar(
    y=instituicoes_plot,
    x=reclamacoes_plot,
    orientation='h',
    marker=dict(
        color=cores_barras,
        line=dict(color='white', width=1.5)
    ),
    text=[f'{int(val):,}' for val in reclamacoes_plot],
    textposition='outside',
    textfont=dict(size=11, color='#333333', family='Arial', weight='bold'),
    hovertemplate=(
        '<b style="font-size:16px; color:#000f44">%{y}</b><br>'
        '<span style="font-size:11px; color:#999999">Ranking: %{customdata[0]}º em SP</span>'
        '<br><br>'
        
        '<span style="font-size:13px; color:#666666"><b>VOLUME DE RECLAMAÇÕES</b></span><br>'
        '<br>'
        '<span style="font-size:22px; color:#000f44"><b>%{x:,.0f}</b></span> '
        '<span style="font-size:11px; color:#777777">reclamações</span>'
        '<br><br>'
        
        '<span style="font-size:13px; color:#666666"><b>PARTICIPAÇÃO EM SP</b></span><br>'
        '<br>'
        '<span style="font-size:18px; color:#FF6B35"><b>%{customdata[1]:.2f}%</b></span> '
        '<span style="font-size:11px; color:#777777">do total do estado</span>'
        '<br><br>'
        
        '<span style="font-size:13px; color:#666666"><b>INDICADORES DE QUALIDADE</b></span><br>'
        '<span style="font-size:12px; color:#444444">'
        '• <b>Nota Média:</b> %{customdata[2]:.2f}/5.0<br>'
        '• <b>Tempo Resposta:</b> %{customdata[3]:.1f} dias<br>'
        '• <b>Taxa Resolução:</b> %{customdata[4]:.1f}%'
        '</span>'
        '<extra></extra>'
    ),
    customdata=np.column_stack([
        ranking_plot,
        pct_total_sp_plot,
        notas_plot,
        tempos_plot,
        pct_resolv_plot
    ])
))

# ============================================================================
# CONFIGURAÇÕES DO LAYOUT
# ============================================================================

fig3.update_layout(
    title={
        'text': (
            f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:26px">Gráfico 3: Top 15 Instituições Financeiras - São Paulo</b><br>'
            '<span style="font-size:15px; color:#666666">Ranking por volume de reclamações - Setor Bancário (2025)</span><br>'
            '<span style="font-size:12px; color:#999999">Fonte: Consumidor.gov.br | Análise: Projeto Agibank</span>'
        ),
        'x': 0.5,
        'xanchor': 'center',
        'font': {'family': 'Arial'}
    },
    xaxis=dict(
        title=dict(
            text='<b>Número de Reclamações</b>',
            font=dict(size=14, color='#333333', family='Arial')
        ),
        showgrid=True,
        gridcolor='#E5E5E5',
        gridwidth=1,
        zeroline=True,
        zerolinecolor='#CCCCCC',
        zerolinewidth=2,
        tickfont=dict(size=11, color='#666666', family='Arial'),
        tickformat=',',
        showline=True,
        linecolor='#CCCCCC',
        linewidth=2
    ),
    yaxis=dict(
        title=None,
        showgrid=False,
        tickfont=dict(size=11, color='#333333', family='Arial'),
        showline=True,
        linecolor='#CCCCCC',
        linewidth=2
    ),
    height=750,  # ✅ Altura aumentada para acomodar melhor
    paper_bgcolor='white',
    plot_bgcolor='#FAFAFA',
    margin=dict(t=140, l=200, r=220, b=100),  # ✅ Margem inferior aumentada
    hoverlabel=dict(
        bgcolor='rgba(255, 255, 255, 0.98)',
        font_size=13,
        font_family='Arial',
        bordercolor=CORES_AGIBANK['azul_escuro'],
        align='left'
    ),
    showlegend=False
)

# ============================================================================
# ANOTAÇÕES (POSICIONAMENTO CORRIGIDO - SEM SOBREPOSIÇÃO)
# ============================================================================

# BOX DE ESTATÍSTICAS (COMPACTO - CANTO SUPERIOR DIREITO)
fig3.add_annotation(
    text=(
        f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:15px">ESTATÍSTICAS - SP</b><br><br>'
        
        f'<span style="font-size:12px; color:#333333">'
        f'<b>Total SP:</b><br>'
        f'<span style="font-size:18px; color:{CORES_AGIBANK["azul_principal"]}"><b>{int(total_sp):,}</b></span> '
        f'<span style="font-size:10px; color:#777777">recl.</span>'
        f'</span><br><br>'
        
        f'<span style="font-size:11px; color:#555555">'
        f'<b>Top 15:</b> '
        f'<span style="font-size:16px; color:#FF6B35"><b>{pct_top15_sp:.1f}%</b></span><br><br>'
        
        f'<b>Média:</b> {int(media_reclamacoes):,}<br>'
        f'<b>Mediana:</b> {int(mediana_reclamacoes):,}<br><br>'
        
        f'<b>Líder:</b> {instituicoes[0][:20]}<br>'
        f'{int(reclamacoes[0]):,} ({pct_total_sp[0]:.1f}%)'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=1.02, y=0.98,  # ✅ Canto superior direito
    xanchor='left', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.97)',
    bordercolor=CORES_AGIBANK['azul_principal'],
    borderwidth=3,
    font=dict(color='#1a1a1a', family='Arial'),
    align='left',
    borderpad=12
)

# LEGENDA DE CORES (ABAIXO DAS ESTATÍSTICAS - BEM SEPARADA)
fig3.add_annotation(
    text=(
        f'<b style="color:{CORES_AGIBANK["azul_escuro"]}; font-size:14px">LEGENDA</b><br><br>'
        f'<span style="font-size:12px; color:#333333">'
        f'<span style="color:{CORES_AGIBANK["azul_escuro"]}">█</span> <b>Crítico</b> (Q4)<br>'
        f'<span style="color:{CORES_AGIBANK["azul_medio"]}">█</span> <b>Alto</b> (Q3)<br>'
        f'<span style="color:{CORES_AGIBANK["azul_principal"]}">█</span> <b>Moderado</b> (Q2)<br>'
        f'<span style="color:{CORES_AGIBANK["verde"]}">█</span> <b>Baixo</b> (Q1)<br><br>'
        f'<span style="font-size:10px; color:#888888">Baseado em quartis<br>do volume</span>'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=1.02, y=0.40,  # ✅ Bem abaixo das estatísticas
    xanchor='left', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.97)',
    bordercolor=CORES_AGIBANK['verde'],
    borderwidth=2,
    font=dict(color='#1a1a1a', family='Arial'),
    align='left',
    borderpad=12
)

# RODAPÉ COM INSIGHT (BEM ABAIXO DO GRÁFICO)
fig3.add_annotation(
    text=(
        f'<span style="font-size:11px; color:#666666">'
        f'<b>Insight:</b> As 15 maiores instituições concentram {pct_top15_sp:.1f}% das reclamações de SP. '
        f'O líder ({instituicoes[0][:20]}) representa {pct_total_sp[0]:.1f}% do total estadual.'
        f'</span>'
    ),
    xref="paper", yref="paper",
    x=0.5, y=-0.10,  # ✅ Mais abaixo para não sobrepor
    xanchor='center', yanchor='top',
    showarrow=False,
    bgcolor='rgba(255,255,255,0.95)',
    bordercolor='#DDDDDD',
    borderwidth=1,
    font=dict(color='#555555', family='Arial'),
    align='center',
    borderpad=8
)

fig3.show()

# ============================================================================
# ETAPA 5: SALVAR
# ============================================================================

print("\n[5/5] Salvando gráfico...")

fig3.write_html(CAMINHO_GRAFICOS / 'grafico_03_top_instituicoes_sp.html')

print(f"✅ Gráfico salvo em: {CAMINHO_GRAFICOS / 'grafico_03_top_instituicoes_sp.html'}")

# ============================================================================
# RESUMO EXECUTIVO
# ============================================================================

print(f"\n" + "="*80)
print("RESUMO EXECUTIVO - TOP INSTITUIÇÕES FINANCEIRAS SP")
print("="*80)

print(f"\n📊 Visão Geral:")
print(f"   Total de reclamações em SP: {int(total_sp):,}")
print(f"   Total de instituições: {len(df_top_sp)}")
print(f"   Top 15 representa: {pct_top15_sp:.1f}% do total")

print(f"\n🏆 Top 15 Instituições - São Paulo:")
print(f"{'Pos':<4} {'Instituição':<40} {'Reclamações':>12} {'% SP':>8} {'Nota':>6}")
print("-" * 80)
for i, (inst, recl, pct, nota) in enumerate(zip(instituicoes, reclamacoes, pct_total_sp, notas), 1):
    print(f"{i:<4} {inst[:38]:<40} {int(recl):>12,} {pct:>7.2f}% {nota:>6.2f}")

# Análise de concentração
print(f"\n📈 Análise de Concentração:")
top3 = np.sum(reclamacoes[:3])
top5 = np.sum(reclamacoes[:5])
top10 = np.sum(reclamacoes[:10])

print(f"   Top 3:  {int(top3):>10,} reclamações ({(top3/total_sp)*100:.1f}% do total SP)")
print(f"   Top 5:  {int(top5):>10,} reclamações ({(top5/total_sp)*100:.1f}% do total SP)")
print(f"   Top 10: {int(top10):>10,} reclamações ({(top10/total_sp)*100:.1f}% do total SP)")
print(f"   Top 15: {int(total_top15):>10,} reclamações ({pct_top15_sp:.1f}% do total SP)")

# Análise de qualidade
print(f"\n⭐ Análise de Qualidade (Top 15):")
print(f"   Nota média: {np.mean(notas):.2f}/5.0")
print(f"   Tempo médio: {np.mean(tempos):.1f} dias")
print(f"   Taxa resolução média: {np.mean(pct_resolv):.1f}%")

print(f"\n   Melhor nota: {instituicoes[np.argmax(notas)][:30]} ({np.max(notas):.2f})")
print(f"   Pior nota: {instituicoes[np.argmin(notas)][:30]} ({np.min(notas):.2f})")

print(f"\n" + "="*80)
# Out:
# ...
# GRAFICO 3: TOP INSTITUIÇÕES FINANCEIRAS - SÃO PAULO
# ...
#
# [1/5] Carregando dados de instituições bancárias de SP...
#    ✅ Dados carregados: 293 instituições
#    Colunas disponíveis: ['instituicao', 'total_reclamacoes', 'nota_media', 'tempo_medio', 'pct_resolvido', 'segmento']
#
#    Amostra dos dados:
#        instituicao  total_reclamacoes  nota_media  tempo_medio  pct_resolvido  \
# 0           Nubank              37381        1.80         3.47           3.52
# 1  Banco Santander              26741        2.07         5.68           7.05
# 2   Banco Bradesco              20734        2.03         8.76           5.60
#
#                                           segmento
# 0  Bancos, Financeiras e Administradoras de Cartão
# 1  Bancos, Financeiras e Administradoras de Cartão
# 2  Bancos, Financeiras e Administradoras de Cartão
#
# [2/5] Preparando dados para visualização...
#    Coluna instituição: instituicao
#    Coluna reclamações: total_reclamacoes
# ...
