# %%
print("Hello World") # Pra dar sorte
# Out:
# Hello World

# %%
"""
Teste Silver DAG - Versão Corrigida
"""

import sys
sys.path.append('../src')

from silver_padronizer import silver_dag

print("🧪 Testando Silver DAG corrigido...")
try:
    result = silver_dag()
    print("✅ Silver DAG: SUCESSO!")

    from pathlib import Path
    import pandas as pd
    
    output_file = Path("../data/silver/consumidor_gov_silver_v1.csv")
    
    if output_file.exists():
        print(f"📁 Arquivo criado: {output_file.name}")
        print(f"📊 Tamanho: {output_file.stat().st_size / (1024*1024):.1f} MB")

        df_check = pd.read_csv(output_file, sep=';', nrows=5)
        print(f"📊 Colunas: {len(df_check.columns)}")
        print(f"📊 Primeiras colunas: {list(df_check.columns)[:5]}")
    else:
        print("❌ Arquivo não encontrado!")

except Exception as e:
    print(f"❌ Erro: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 Testando Silver DAG corrigido...
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messages'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 1150, in emit
#     msg = self.format(record)
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 998, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 714, in format
#     s = self.formatMessage(record)
# ...

# %%
"""
Teste Silver DAG - Versão Corrigida Final
"""

import sys
sys.path.append('../src')

# Limpa handlers anteriores do logging
import logging
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

from silver_padronizer import silver_dag

print("🧪 Testando Silver DAG corrigido...")
try:
    result = silver_dag()
    print("✅ Silver DAG: SUCESSO!")
    print(f"📊 Shape final: {result.shape}")
    
except Exception as e:
    print(f"❌ Erro: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 Testando Silver DAG corrigido...
# Error DAG Silver: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Traceback (most recent call last):
#   File "C:\Users\ana.leandro\AppData\Local\Temp\ipykernel_48964\1564493396.py", line 17, in <module>
#     result = silver_dag()
#   File "c:\Users\ana.leandro\Desktop\projeto_mediacao_bancaria\notebooks\../src\silver_padronizer.py", line 152, in silver_dag
#   File "c:\Users\ana.leandro\Desktop\projeto_mediacao_bancaria\env\Lib\site-packages\pandas\core\generic.py", line 1580, in __nonzero__
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ❌ Erro: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Teste isolado da função
import pandas as pd
import sys
sys.path.append('../src')

# Limpar logging
import logging
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from silver_padronizer import standardize_column_names

# Criar DataFrame de teste
test_df = pd.DataFrame({
    'Coluna Com Espaço': [1, 2, 3],
    'Região': [4, 5, 6],
    'MAIUSCULA': [7, 8, 9]
})

print("📊 DataFrame original:")
print(test_df.columns.tolist())

result = standardize_column_names(test_df)

print("\n📊 DataFrame após padronização:")
print(result.columns.tolist())
print(f"\n✅ Tipo retornado: {type(result)}")
# Out:
# 2026-02-16 12:59:33,667 - INFO - Padronizando nomes das colunas...
# 2026-02-16 12:59:33,674 - INFO - Principais mudanças nas colunas:
# 2026-02-16 12:59:33,675 - INFO -   Coluna Com Espaço -> coluna_com_espaco
# 2026-02-16 12:59:33,676 - INFO -   Região -> regiao
# 2026-02-16 12:59:33,677 - INFO -   MAIUSCULA -> maiuscula
# 2026-02-16 12:59:33,677 - INFO - ✅ Colunas padronizadas: 3 colunas
# 📊 DataFrame original:
# ['Coluna Com Espaço', 'Região', 'MAIUSCULA']
#
# 📊 DataFrame após padronização:
# ['coluna_com_espaco', 'regiao', 'maiuscula']
#
# ✅ Tipo retornado: <class 'pandas.core.frame.DataFrame'>

# %%
"""
Teste Silver DAG - Versão Corrigida Final
"""

import sys
sys.path.append('../src')

# Limpa handlers anteriores do logging
import logging
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

from silver_padronizer import silver_dag

print("🧪 Testando Silver DAG corrigido...")
try:
    result = silver_dag()
    print("✅ Silver DAG: SUCESSO!")
    print(f"📊 Shape final: {result.shape}")
    
except Exception as e:
    print(f"❌ Erro: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 Testando Silver DAG corrigido...
# Error DAG Silver: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Traceback (most recent call last):
#   File "C:\Users\ana.leandro\AppData\Local\Temp\ipykernel_48964\1564493396.py", line 17, in <module>
#     result = silver_dag()
#   File "c:\Users\ana.leandro\Desktop\projeto_mediacao_bancaria\notebooks\../src\silver_padronizer.py", line 152, in silver_dag
#     def silver_dag():
#                ^^
#   File "c:\Users\ana.leandro\Desktop\projeto_mediacao_bancaria\env\Lib\site-packages\pandas\core\generic.py", line 1580, in __nonzero__
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ❌ Erro: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import sys
sys.path.append('../src')

# Limpa handlers anteriores do logging
import logging
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

from silver_padronizer import load_bronze_data

load_bronze_data()
# Out:
#         Região  UF          Cidade Sexo        Faixa Etária  Ano Abertura  \
# 0           SE  MG  Belo Horizonte    M  entre 61 a 70 anos          2024
# 1           CO  MT          Cuiabá    M  entre 31 a 40 anos          2024
# 2           NE  SE         Aracaju    M  entre 21 a 30 anos          2024
# 3           CO  MS    Campo Grande    F  entre 61 a 70 anos          2024
# 4           SE  RJ  Rio de Janeiro    M  entre 41 a 50 anos          2024
# ...        ...  ..             ...  ...                 ...           ...
# 2567090     NE  CE          Russas    F  entre 31 a 40 anos          2025
# 2567091     SE  SP          Suzano    M  entre 41 a 50 anos          2025
# 2567092     S   SC         Palhoça    O  entre 31 a 40 anos          2025
# 2567093     SE  SP  Ribeirão Pires    M         até 20 anos          2025
# 2567094     SE  SP           Cotia    M  entre 41 a 50 anos          2025
#
#          Mês Abertura Data Abertura Data Resposta Data Finalização  ...  \
# ...

# %%
"""
Teste de importação para identificar o erro
"""
import sys
sys.path.append('../src')

print("🧪 Tentando importar o módulo...")

try:
    # Importar apenas o módulo (sem executar funções)
    import silver_padronizer
    print("✅ Módulo importado com sucesso!")
    
    # Listar funções disponíveis
    functions = [name for name in dir(silver_padronizer) if callable(getattr(silver_padronizer, name)) and not name.startswith('_')]
    print(f"\n📋 Funções disponíveis: {functions}")
    
except Exception as e:
    print(f"❌ Erro ao importar: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 Tentando importar o módulo...
# ✅ Módulo importado com sucesso!
#
# 📋 Funções disponíveis: ['Path', 'convert_categorical_columns', 'convert_temporal_columns', 'datetime', 'final_cleanup', 'load_bronze_data', 'silver_dag', 'standardize_column_names']

# %%
"""
Teste Silver DAG - Versão Corrigida Final
"""

import sys
sys.path.append('../src')

# Limpa handlers anteriores do logging
import logging
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

from silver_padronizer import silver_dag

print("🧪 Testando Silver DAG corrigido...")
try:
    result = silver_dag()
    print("✅ Silver DAG: SUCESSO!")
    print(f"📊 Shape final: {result.shape}")
    
except Exception as e:
    print(f"❌ Erro: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 Testando Silver DAG corrigido...
# Error DAG Silver: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ❌ Erro: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Traceback (most recent call last):
#   File "C:\Users\ana.leandro\AppData\Local\Temp\ipykernel_48964\1564493396.py", line 17, in <module>
#     result = silver_dag()
#   File "c:\Users\ana.leandro\Desktop\projeto_mediacao_bancaria\notebooks\../src\silver_padronizer.py", line 152, in silver_dag
#   File "c:\Users\ana.leandro\Desktop\projeto_mediacao_bancaria\env\Lib\site-packages\pandas\core\generic.py", line 1580, in __nonzero__
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Execute esta célula PRIMEIRO
# %reset -f

# Limpar todos os imports
import sys
modules_to_remove = [m for m in sys.modules if 'silver_padronizer' in m]
for module in modules_to_remove:
    del sys.modules[module]

print("✅ Cache limpo!")
# Out:
# ✅ Cache limpo!

# %%
# Agora importe novamente
import sys
sys.path.append('../src')

import logging
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

from silver_padronizer import silver_dag

print("🧪 Testando Silver DAG...")
try:
    result = silver_dag()
    print("✅ Silver DAG: SUCESSO!")
    print(f"📊 Shape final: {result.shape}")
    
except Exception as e:
    print(f"❌ Erro: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# 2026-02-16 13:20:42,853 - INFO - Iniciando DAG Silver...
# 2026-02-16 13:20:42,854 - INFO - Carregando dados Bronze...
# 2026-02-16 13:20:42,854 - INFO - Carregando dados da camada Bronze...
# 🧪 Testando Silver DAG...
# 2026-02-16 13:20:51,483 - INFO - ✅ Dados carregados: 2567095 registros, 30 colunas
# 2026-02-16 13:20:51,484 - INFO -    Padronizando colunas...
# 2026-02-16 13:20:51,485 - INFO - Padronizando nomes das colunas...
# 2026-02-16 13:20:51,487 - INFO - Principais mudanças nas colunas (24 total):
# 2026-02-16 13:20:51,488 - INFO -   Região -> regiao
# 2026-02-16 13:20:51,489 - INFO -   UF -> uf
# 2026-02-16 13:20:51,490 - INFO -   Cidade -> cidade
# 2026-02-16 13:20:51,491 - INFO -   Sexo -> sexo
# 2026-02-16 13:20:51,491 - INFO -   Faixa Etária -> faixa_etaria
# 2026-02-16 13:20:51,492 - INFO - ✅ Colunas padronizadas: 30 colunas
# 2026-02-16 13:20:51,492 - INFO -    Convertendo colunas temporais...
# 2026-02-16 13:20:51,493 - INFO - Convertendo colunas temporais...
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/silver/consumidor_gov_silver_v1.csv", sep=';')
df.head()
# Out:
#   regiao  uf          cidade sexo        faixa_etaria  ano_abertura  \
# 0     SE  MG  Belo Horizonte    M  entre 61 a 70 anos          2024
# 1     CO  MT          Cuiabá    M  entre 31 a 40 anos          2024
# 2     NE  SE         Aracaju    M  entre 21 a 30 anos          2024
# 3     CO  MS    Campo Grande    F  entre 61 a 70 anos          2024
# 4     SE  RJ  Rio de Janeiro    M  entre 41 a 50 anos          2024
#
#    mes_abertura data_abertura data_resposta data_finalizacao  ... respondida  \
# 0            11    2024-11-01    2024-11-11       2025-01-20  ...          S
# 1            11    2024-11-01    2024-11-11       2025-01-15  ...          S
# 2            11    2024-11-01    2024-11-11       2025-01-12  ...          S
# 3            11    2024-11-01    2024-11-08       2025-01-27  ...          S
# 4            11    2024-11-01    2024-11-11       2025-01-17  ...          S
#
#               situacao avaliacao_reclamacao nota_do_consumidor  \
# ...

# %%
df.columns
# Out:
# Index(['regiao', 'uf', 'cidade', 'sexo', 'faixa_etaria', 'ano_abertura',
#        'mes_abertura', 'data_abertura', 'data_resposta', 'data_finalizacao',
#        'prazo_resposta', 'tempo_resposta', 'nome_fantasia',
#        'segmento_de_mercado', 'area', 'assunto', 'grupo_problema', 'problema',
#        'como_comprou_contratou', 'procurou_empresa', 'respondida', 'situacao',
#        'avaliacao_reclamacao', 'nota_do_consumidor', 'data_source',
#        'file_origin', 'processed_at', 'file_month', 'is_agibank',
#        'quality_score'],
#       dtype='object')

# %%
df["prazo_resposta"].head()
# Out:
# 0    2024-11-11
# 1    2024-11-11
# 2    2024-11-11
# 3    2024-11-11
# 4    2024-11-11
# Name: prazo_resposta, dtype: object

# %%
df_check_uf = df["uf"].unique()

display(df_check_uf)
# Out:
# array(['MG', 'MT', 'SE', 'MS', 'RJ', 'SC', 'PR', 'BA', 'CE', 'ES', 'SP',
#        'RO', 'GO', 'AM', 'DF', 'PE', 'PI', 'MA', 'PA', 'RS', 'AL', 'TO',
#        'AC', 'RN', 'PB', 'AP', 'RR'], dtype=object)

# %%
df_check_cidade = df["cidade"].unique()

display(df_check_cidade) # ~+1063 cidades relatadas na análse inicial
# Out:
# array(['Belo Horizonte', 'Cuiabá', 'Aracaju', ..., 'Dez de Maio',
#        'Piedade do Paraopeba', 'Penido'], shape=(6633,), dtype=object)

# %%
df_check_area = df["area"].unique()

display(df_check_area)
# Out:
# array(['Serviços Financeiros', 'Demais Serviços ', 'Telecomunicações',
#        'Transportes', 'Saúde', 'Produtos de Telefonia e Informática',
#        'Alimentos', 'Água, Energia, Gás', 'Demais Produtos', 'Habitação',
#        'Produtos Eletrodomésticos e Eletrônicos', 'Turismo/Viagens',
#        'Educação', 'Loterias, Apostas e Promoções Comerciais'],
#       dtype=object)
